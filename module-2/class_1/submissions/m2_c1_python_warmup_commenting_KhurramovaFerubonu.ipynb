# %% [markdown]
# # Python Warmup -- Module 2, Class 1
#
# This notebook covers the Python fundamentals you need for data work:
# - Variables and data types
# - Functions
# - Loops
#
# Each section has examples first, then TODO exercises for you to complete.

# %% [markdown]
# ---
# ## 1. Variables and Data Types
#
# Python has four core data types you will use constantly:
# - **int** -- whole numbers (subscriber count, age)
# - **float** -- decimal numbers (bill amount, accuracy)
# - **str** -- text (customer name, region)
# - **bool** -- True or False (is_active, payment_on_time)
# - **list** -- ordered collection (monthly bills, feature names)

# %% [markdown]
# homework

# %%
# commenting

# confirming integers
subscriber_count = 10_000_000
age = 25

# confirming floats
monthly_bill = 89_500.50
accuracy = 0.95

# confirming strings
customer_name = "Abdullayev Jasur"
region = "Tashkent"

# confirming booleans
is_active = True
payment_on_time = False

# confirming lists(including different data types)
monthly_bills = [85000, 92000, 78000, 95000, 88000]
regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana"]

# checking data types
print(f"subscriber_count: {subscriber_count} (type: {type(subscriber_count).__name__})")
print(f"monthly_bill:     {monthly_bill} (type: {type(monthly_bill).__name__})")
print(f"customer_name:    {customer_name} (type: {type(customer_name).__name__})")
print(f"is_active:        {is_active} (type: {type(is_active).__name__})")
print(f"monthly_bills:    {monthly_bills} (type: {type(monthly_bills).__name__})")
# Out:
# subscriber_count: 10000000 (type: int)
# monthly_bill:     89500.5 (type: float)
# customer_name:    Abdullayev Jasur (type: str)
# is_active:        True (type: bool)
# monthly_bills:    [85000, 92000, 78000, 95000, 88000] (type: list)

# %% [markdown]
# self writing commands on my own

# %%
course_name = "Data Science"
lesson_number = 5
is_hard = False
print (f" course_name={course_name} type: {type(course_name) . __name__}")
print(f" lesson_number= {lesson_number} type: {type(lesson_number) . __name__}")
print(f" is_it_hard? {is_hard} type: {type(is_hard) . __name__} ")
# Out:
#  course_name=Data Science type: str
#  lesson_number= 5 type: int
#  is_it_hard? False type: bool

# %%
subscriber_count = 10_000_000
age = 25
monthly_bill = 89_500.50
accuracy = 0.95
customer_name = "Abdullayev Jasur"
region = "Tashkent"
is_active = True
payment_on_time = False
monthly_bills = [85000, 92000, 78000, 95000, 88000]
regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana"]

print(f"subscriber_count: {subscriber_count} (type:{type (subscriber_count) .__name__}) ")
print(f"monthly_bill: {monthly_bill} type : {type (monthly_bill) . __name__} ")
print (f"customer_name: {customer_name} (type: {type (customer_name) .__name__})")
print (f"customer_age {age} (type: {type(age).__name__})")
print (f"customer_region {region} (type {type (region).__name__})")
# Out:
# subscriber_count: 10000000 (type:int)
# monthly_bill: 89500.5 type : float
# customer_name: Abdullayev Jasur (type: str)
# customer_age 25 (type: int)
# customer_region Tashkent (type str)

# %%
print(f"First bill: {monthly_bills[0]}") #[0] showing the first one of the list
print(f"Last bill:  {monthly_bills[-1]}") #[-1] showing the first one of the list
print(f"First 3 bills: {monthly_bills[:3]}") #[:3] showing the first 3 ones of the list
print(f"Number of bills: {len(monthly_bills)}") # showing the total list
# Append means adding one to the list
monthly_bills.append(91000)  #.append this is particularly function for append 
print(f"After append: {monthly_bills}") #hsowing the  list with the extra one
# Out:
# First bill: 85000
# Last bill:  88000
# First 3 bills: [85000, 92000, 78000]
# Number of bills: 5
# After append: [85000, 92000, 78000, 95000, 88000, 91000]

# %% [markdown]
# self writing commands on my own with list operations

# %%
monthly_bills = [85000, 92000, 78000, 77000, 88000, 95000]
print (f" First bill: {monthly_bills[0]}")  #[0] showing the first one of the list
print (f" Last bill: {monthly_bills[-1]}") #[-1] showing the first one of the list
print (f" First 3 bill: {monthly_bills[:3]}") #[:3] showing the first 3 ones of the list
print (f" Last 3 bill: {monthly_bills[3:]}") #[3:] showing the first 3 ones of the list
print (f" Number of bills: {len (monthly_bills)}") # showing the total list
monthly_bills.append(1000000) # Append means adding one to the list
print (f" After append: { (monthly_bills)}") #hsowing the  list with the extra one
# Out:
#  First bill: 85000
#  Last bill: 95000
#  First 3 bill: [85000, 92000, 78000]
#  Last 3 bill: [77000, 88000, 95000]
#  Number of bills: 6
#  After append: [85000, 92000, 78000, 77000, 88000, 95000, 1000000]

# %%
# Variables exercise ---
# Create variables for a telecom customer profile:

# Create an integer variable for the customer's age
customer_age = 24

# Create a float variable for their monthly data usage in GB
data_usage_gb = 15.7

#  Create a string variable for their city
city = "Tashkent"

# Create a boolean for whether they have a contract (vs prepaid)
has_contract = True

#  Create a list of their last 6 monthly bills (make up reasonable numbers in soum)
bills = [85000, 92000, 78000, 88000, 95000, 91000]

print(f"data_usage_gb {data_usage_gb} (type {type (data_usage_gb).__name__})")
print(f"customer_age {customer_age} (type {type (customer_age).__name__})")
print(f"city {city} (type {type (city).__name__})")
print(f"has_contract {has_contract} (type {type (has_contract).__name__})")
print(f"bills {bills} (type {type (bills).__name__})")
# Out:
# data_usage_gb 15.7 (type float)
# customer_age 24 (type int)
# city Tashkent (type str)
# has_contract True (type bool)
# bills [85000, 92000, 78000, 88000, 95000, 91000] (type list)

# %% [markdown]
# ---
# ## 2. Dictionaries
#
# A dictionary stores key-value pairs. Think of it as a single row in a database table -- keys are column names, values are the data.

# %%
# --- EXAMPLE ---

customer = {
    "id": "UZT-001234",
    "name": "Karimov Sherzod",
    "region": "Tashkent",
    "monthly_spend": 125000,
    "is_active": True,
    "plan": "Premium"
}

# Access values by key
print(f"Customer: {customer['name']}")
print(f"Region:   {customer['region']}")
print(f"Spend:    {customer['monthly_spend']} soum")

# Add a new key
customer["tenure_months"] = 24
print(f"\nFull record: {customer}")
# Out:
# Customer: Karimov Sherzod
# Region:   Tashkent
# Spend:    125000 soum
#
# Full record: {'id': 'UZT-001234', 'name': 'Karimov Sherzod', 'region': 'Tashkent', 'monthly_spend': 125000, 'is_active': True, 'plan': 'Premium', 'tenure_months': 24}

# %%
# self-study
product = {
    "id": "UZB000COSMETICS001SCINCARE003CLEANSING004",
    "name": "Tony Moly-AloeVera",
    "made_in": "Korea",
    "price": 120000,
    "discount_market": "Uzum Market",
    "discount_price": 80000
}
print(f"Product id: {product['id']}")
print(f"Product name: {product['name']}")
print(f"Made in {product['made_in']}")
print(f"Product's original price: {product['price']}UZS")
print(f"If You buy it from {product['discount_market']},")
print(f"You will pay less with discount price, {product['discount_price']}UZS")

# add new keys about the product
product["uzum_nasiya"] = 100000  # total uzum nasiya 100000 UZS
product["tenure_months"] = 3   # the maintain of uzum nasiya 3 months
product["tenure_payment"] = 33333.33
print(f"Also You can buy with Uzum Nasiya, total {product ['uzum_nasiya']} UZS")
print(f"You should pay it, just for {product['tenure_months']} months, with {product['tenure_payment']} UZS for per month ")

#printing all about the product with added infos
print(f"\nFull info about the product: {product}")
# Out:
# Product id: UZB000COSMETICS001SCINCARE003CLEANSING004
# Product name: Tony Moly-AloeVera
# Made in Korea
# Product's original price: 120000UZS
# If You buy it from Uzum Market,
# You will pay less with discount price, 80000UZS
# Also You can buy with Uzum Nasiya, total 100000 UZS
# You should pay it, just for 3 months, with 33333.33 UZS for per month
#
# Full info about the product: {'id': 'UZB000COSMETICS001SCINCARE003CLEANSING004', 'name': 'Tony Moly-AloeVera', 'made_in': 'Korea', 'price': 120000, 'discount_market': 'Uzum Market', 'discount_price': 80000, 'uzum_nasiya': 100000, 'tenure_months': 3, 'tenure_payment': 33333.33}

# %% [markdown]
# ---
# ## 3. Functions
#
# Functions take inputs, perform an operation, and return an output. They let you write reusable, modular code.
#
# In ML, every step of a pipeline is typically a function: load_data(), clean_data(), train_model(), evaluate().

# %%
# --- EXAMPLE: calculate_average ---

def calculate_average(numbers):
    """Calculate the average of a list of numbers."""
    total = sum(numbers)
    count = len(numbers)
    return total / count

bills = [85000, 92000, 78000, 95000, 88000, 91000]
avg_bill = calculate_average(bills)
print(f"Average monthly bill: {avg_bill:,.0f} soum")
# Out:
# Average monthly bill: 88,167 soum

# %%
# --- EXAMPLE: function with multiple returns ---

def describe_bills(bills):
    """Return basic statistics for a list of bills."""
    avg = sum(bills) / len(bills)
    minimum = min(bills)
    maximum = max(bills)
    return avg, minimum, maximum

avg, low, high = describe_bills(bills)
print(f"Average: {avg:,.0f} | Min: {low:,.0f} | Max: {high:,.0f}")
# Out:
# Average: 88,167 | Min: 78,000 | Max: 95,000

# %%
#  studying independently with functions
def calculate_average(numbers) :
    """Calculate the average of a list of numbers."""
    total = sum(numbers)
    count = len(numbers)
    return total / count
def classify_customer(monthly_spend):
    if monthly_spend >= 150000:
        return "premium"
    elif monthly_spend >= 50000:
        return "standard"
    else:
        return "basic"
# Testing my function:
print(classify_customer(200000))  # should print "premium"
print(classify_customer(75000))   # should print "standard"
print(classify_customer(30000))   # should print "basic"

bills = [200000, 192000, 75000, 95000, 88000, 30000]
avg = calculate_average(bills)
status = classify_customer(avg)
print(f"Average monthly bill: {avg:,.0f} soum")
print(f"Average spend: {avg:,.0f} UZS")
print(f"Customer status: {status}")  #status of avg
# Out:
# premium
# standard
# basic
# Average monthly bill: 113,333 soum
# Average spend: 113,333 UZS
# Customer status: standard

# %%
def calculate_churn_rate(total_customers, churned_customers):
    # Logic: (part / whole) * 100
    rate = (churned_customers / total_customers) * 100
    return rate

# Testing the function:
print(calculate_churn_rate(10000, 350)) # This will output 3.5
# Out:
# 3.5000000000000004

# %%
# Function 1: Bills Stats
def describe_bills(bills):
    avg = sum(bills) / len(bills)
    minimum = min(bills)
    maximum = max(bills)
    return avg, minimum, maximum

# Function 2: Customer Classification
def classify_customer(avg_spend):
    if avg_spend > 150000:
        return "Premium"
    elif avg_spend >= 50000:
        return "Standard"
    else:
        return "Basic"

# Function 3: Churn Rate 
def calculate_churn_rate(total_customers, churned_customers):
    rate = (churned_customers / total_customers) * 100
    return rate

# --- EXECUTION ---
monthly_bills = [120000, 150000, 90000, 110000, 60000, 160000, 40000]
total_clients = 10000
lost_clients = 350

# Logic Flow
average, low, high = describe_bills(monthly_bills)
tier = classify_customer(average)
churn = calculate_churn_rate(total_clients, lost_clients)

# Final Output
print(f"--- Business Report ---")
print(f"Average Revenue per User: {average:,.0f} UZS")
print(f"Customer Segment: {tier}")
print(f"Monthly Churn Rate: {churn}%")
# Out:
# --- Business Report ---
# Average Revenue per User: 117,500 UZS
# Customer Segment: Standard
# Monthly Churn Rate: 3.5000000000000004%

# %% [markdown]
# ---
# ## 4. Loops
#
# Loops let you repeat an operation across a collection. In data work, you iterate over rows, columns, files, or parameter values constantly.

# %%
# --- EXAMPLE: basic for loop ---

regions = ["Tashkent", "Samarkand", "Bukhara", "Fergana", "Namangan"]

for region in regions:
    print(f"Processing data for: {region}")
# Out:
# Processing data for: Tashkent
# Processing data for: Samarkand
# Processing data for: Bukhara
# Processing data for: Fergana
# Processing data for: Namangan

# %%
#exercise
products = ["CeraVe Foaming Facial Cleanser", "The Ordinary Squalane Cleanser", "Cetaphil Daily Facial Cleanser", "CeraVe Moisturizing Lotion", "Neutrogena Hydro Boost Gel", "Nivea Soft Cream", "The Ordinary Niacinamide 10%", "The Ordinary Alpha Arbutin 2%", "The Ordinary Hyaluronic Acid 2%", "CeraVe AM SPF 30", "Neutrogena Sunscreen", "Eucerin Sunscreen"]
for i, product in enumerate(products, start=1):
    print(f"Processing data for Product {i}: {product}")
# Out:
# Processing data for Product 1: CeraVe Foaming Facial Cleanser
# Processing data for Product 2: The Ordinary Squalane Cleanser
# Processing data for Product 3: Cetaphil Daily Facial Cleanser
# Processing data for Product 4: CeraVe Moisturizing Lotion
# Processing data for Product 5: Neutrogena Hydro Boost Gel
# Processing data for Product 6: Nivea Soft Cream
# Processing data for Product 7: The Ordinary Niacinamide 10%
# Processing data for Product 8: The Ordinary Alpha Arbutin 2%
# Processing data for Product 9: The Ordinary Hyaluronic Acid 2%
# Processing data for Product 10: CeraVe AM SPF 30
# Processing data for Product 11: Neutrogena Sunscreen
# Processing data for Product 12: Eucerin Sunscreen

# %%
# --- EXAMPLE: enumerate (index + value) ---
# enumerate gives you both the position and the value

monthly_bills = [85000, 92000, 78000, 95000, 88000, 91000]

for i, bill in enumerate(monthly_bills):
    print(f"Month {i + 1}: {bill:,} soum")
# Out:
# Month 1: 85,000 soum
# Month 2: 92,000 soum
# Month 3: 78,000 soum
# Month 4: 95,000 soum
# Month 5: 88,000 soum
# Month 6: 91,000 soum

# %%
#xercise
product_prices = [285000, 110000, 310000, 200000, 210000, 200000, 285000, 250000, 120000, 260000, 240000, 330000]
for i, price in enumerate(product_prices):
    print(f"Product {i + 1}: {price:,}UZS")
# Out:
# Product 1: 285,000UZS
# Product 2: 110,000UZS
# Product 3: 310,000UZS
# Product 4: 200,000UZS
# Product 5: 210,000UZS
# Product 6: 200,000UZS
# Product 7: 285,000UZS
# Product 8: 250,000UZS
# Product 9: 120,000UZS
# Product 10: 260,000UZS
# Product 11: 240,000UZS
# Product 12: 330,000UZS

# %%
# --- EXAMPLE: loop with conditional ---

customers = [
    {"name": "Alisher", "spend": 200000},
    {"name": "Dilnoza", "spend": 45000},
    {"name": "Bobur",   "spend": 120000},
    {"name": "Malika",  "spend": 35000},
    {"name": "Rustam",  "spend": 180000},
]

print("High-value customers (spend > 100,000):")
for c in customers:
    if c["spend"] > 100000:
        print(f"  {c['name']}: {c['spend']:,} soum")
# Out:
# High-value customers (spend > 100,000):
#   Alisher: 200,000 soum
#   Bobur: 120,000 soum
#   Rustam: 180,000 soum

# %%
#exercise
products = ["CeraVe Foaming Facial Cleanser", "The Ordinary Squalane Cleanser", "Cetaphil Daily Facial Cleanser", "CeraVe Moisturizing Lotion", "Neutrogena Hydro Boost Gel", "Nivea Soft Cream", "The Ordinary Niacinamide 10%", "The Ordinary Alpha Arbutin 2%", "The Ordinary Hyaluronic Acid 2%", "CeraVe AM SPF 30", "Neutrogena Sunscreen", "Eucerin Sunscreen"]
product_prices = [285000, 110000, 310000, 200000, 210000, 98000, 285000, 250000, 120000, 260000, 240000, 330000]

print("--- Product Classification Report ---")

for i, price in enumerate(product_prices):
    product_name = products[i]
    if price > 200000:
        category = "Expensive/Premium"
    elif price >= 100000:
        category = "Standard Product"
    else:
        category = "Budget-friendly"
        
    print(f"Product {i+1}: {product_name} | Price: {price:,} UZS | Category: {category}")
# Out:
# --- Product Classification Report ---
# Product 1: CeraVe Foaming Facial Cleanser | Price: 285,000 UZS | Category: Expensive/Premium
# Product 2: The Ordinary Squalane Cleanser | Price: 110,000 UZS | Category: Standard Product
# Product 3: Cetaphil Daily Facial Cleanser | Price: 310,000 UZS | Category: Expensive/Premium
# Product 4: CeraVe Moisturizing Lotion | Price: 200,000 UZS | Category: Standard Product
# Product 5: Neutrogena Hydro Boost Gel | Price: 210,000 UZS | Category: Expensive/Premium
# Product 6: Nivea Soft Cream | Price: 98,000 UZS | Category: Budget-friendly
# Product 7: The Ordinary Niacinamide 10% | Price: 285,000 UZS | Category: Expensive/Premium
# Product 8: The Ordinary Alpha Arbutin 2% | Price: 250,000 UZS | Category: Expensive/Premium
# Product 9: The Ordinary Hyaluronic Acid 2% | Price: 120,000 UZS | Category: Standard Product
# Product 10: CeraVe AM SPF 30 | Price: 260,000 UZS | Category: Expensive/Premium
# Product 11: Neutrogena Sunscreen | Price: 240,000 UZS | Category: Expensive/Premium
# Product 12: Eucerin Sunscreen | Price: 330,000 UZS | Category: Expensive/Premium

# %%
customers = [
    {"name": "Alisher", "spend": 200000},
    {"name": "Dilnoza", "spend": 45000},
    {"name": "Bobur",   "spend": 120000},
    {"name": "Malika",  "spend": 35000},
    {"name": "Rustam",  "spend": 180000},
]
for customer in customers:
    spend = customer["spend"]
    tier = classify_customer(spend)
    name = customer["name"]
    print(f"Name: {name}, Tier: {tier}")
# Out:
# Name: Alisher, Tier: Premium
# Name: Dilnoza, Tier: Basic
# Name: Bobur, Tier: Standard
# Name: Malika, Tier: Basic
# Name: Rustam, Tier: Premium

# %%
# TODO 2: Given the list of scores below, use enumerate to print each score
#         with its rank (starting from 1), and mark scores above 90 with " -- HIGH"
#
# Expected output:
#   Rank 1: 72
#   Rank 2: 95 -- HIGH
#   Rank 3: 88
#   ...

scores = [72, 95, 88, 61, 93, 77, 85, 91, 68, 99]

scores = [72, 95, 88, 61, 93, 77, 85, 91, 68, 99]

# Using enumerate to get the rank (starting from 1) and the score
for rank, score in enumerate(scores, start=1):
    
    # Checking if the score is above 90
    if score > 90:
        print(f"Rank {rank}: {score} -- HIGH")
    else:
        print(f"Rank {rank}: {score} -- STANDARD")
# Out:
# Rank 1: 72 -- STANDARD
# Rank 2: 95 -- HIGH
# Rank 3: 88 -- STANDARD
# Rank 4: 61 -- STANDARD
# Rank 5: 93 -- HIGH
# Rank 6: 77 -- STANDARD
# Rank 7: 85 -- STANDARD
# Rank 8: 91 -- HIGH
# Rank 9: 68 -- STANDARD
# Rank 10: 99 -- HIGH

# %%
#  Write a loop that computes the total and average of the scores list.
#         Do NOT use sum() or len() -- compute manually with a loop.
#         Print: "Total: <total>, Average: <average>"

scores = [72, 95, 88, 61, 93, 77, 85, 91, 68, 99]

# Step 1: Initialize counters
total_sum = 0
count = 0

# Step 2: Loop through each score
for s in scores:
    total_sum += s  # Add the score to the total
    count += 1      # Increment the count by 1

# Step 3: Compute the average
average = total_sum / count

# Step 4: Output the result
print(f"Total: {total_sum}, Average: {average}")
# Out:
# Total: 829, Average: 82.9

# %% [markdown]
# ---
# ## 5. Putting It All Together
#
# Combine variables, functions, and loops to solve a mini data task.

# %%
# --- TODO: Final exercise ---
#
# You have a dataset of 8 customers (list of dictionaries).
# Write code that:
# 1. Loops through each customer
# 2. Classifies them into tiers (use classify_customer or write inline logic)
# 3. Counts how many customers are in each tier
# 4. Prints a summary: "Premium: X, Standard: Y, Basic: Z"

customers_data = [
    {"id": 1, "name": "Anvar",   "monthly_spend": 210000},
    {"id": 2, "name": "Nilufar", "monthly_spend": 55000},
    {"id": 3, "name": "Sardor",  "monthly_spend": 180000},
    {"id": 4, "name": "Gulnora", "monthly_spend": 32000},
    {"id": 5, "name": "Timur",   "monthly_spend": 95000},
    {"id": 6, "name": "Madina",  "monthly_spend": 160000},
    {"id": 7, "name": "Otabek",  "monthly_spend": 47000},
    {"id": 8, "name": "Zarina",  "monthly_spend": 125000},
]

tier_counts = {"Premium": 0, "Standard": 0, "Basic": 0}
# 1. Loop through each customer
for customer in customers_data:
    spend = customer["monthly_spend"]
    
    # 2. Classify into tiers
    if spend > 150000:
        tier = "Premium"
    elif spend >= 50000:
        tier = "Standard"
    else:
        tier = "Basic"
    
    # 3. Update the counts
    tier_counts[tier] += 1

# 4. Print the summary
print(f"Premium: {tier_counts['Premium']}, Standard: {tier_counts['Standard']}, Basic: {tier_counts['Basic']}")
# Out:
# Premium: 3, Standard: 3, Basic: 2
