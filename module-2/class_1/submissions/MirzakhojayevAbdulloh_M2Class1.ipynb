# %%
print("Hello AI/ML")
# Out:
# Hello World

# %%
age = 22
gpa = 3.85
name = "Aziz"
is_student = True
scores = [85, 92, 78, 95, 88]

print(age, type(age))
print(gpa, type(gpa))
print(name, type(name))
print(is_student, type(is_student))
print(scores, type(scores))
# Out:
# 22 <class 'int'>
# 3.85 <class 'float'>
# Aziz <class 'str'>
# True <class 'bool'>
# [85, 92, 78, 95, 88] <class 'list'>

# %%
def calculate_average(numbers):
  total = sum(numbers)
  count = len(numbers)
  return total / count

test1 = [80, 90, 70, 85, 95]
test2 = [55, 62, 48, 71]
print("Average 1:", calculate_average(test1))
print("Average 2:", calculate_average(test2))
# Out:
# Average 1: 84.0
# Average 2: 59.0

# %%
topics = ["Introduction", "Python Fundamentals", "Numpy", "Pandas", "Scikit-learn"]
for index, topic in enumerate(topics):
  print(f"Index {index}: {topic}")
# Out:
# Index 0: Introduction
# Index 1: Python Fundamentals
# Index 2: Numpy
# Index 3: Pandas
# Index 4: Scikit-learn

# %%
import random
exam_scores = [random.randint(0, 100) for _ in range(10)]
print("Scores:", exam_scores)

avg = calculate_average(exam_scores)
print(f"Class average: {avg:.1f}")

if avg >= 60:
  print("Result: PASS")
else:
  print("Result: FAIL")
# Out:
# Scores: [29, 34, 6, 100, 78, 57, 37, 43, 14, 17]
# Class average: 41.5
# Result: FAIL

# %%
# Temperature converter (Celsius ↔ Fahrenheit)

def celsius_to_fahrenheit(celsius):
  return (celsius * 9/5) + 32

# List averager (takes a list, returns average)

def list_average(nums):
  return sum(nums) / len(nums)

list_average([1, 2, 3, 4, 5])

# One function of your choice

def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n-1) + fibonacci(n-2)
