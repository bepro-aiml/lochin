# %%
print ("Hello, AI/ML")
# Out:
# Hello, AI/ML

# %%
age = 20
gpa = 4.0
name = "Abdulaziz"
is_student = True
scores = [85, 92, 78, 95, 88]
print(age, type(age))
print(gpa, type(gpa))
print(name, type(name))
print(is_student, type(is_student))
print(scores, type(scores))
# that was good but I am still learning it
# Out:
# 20 <class 'int'>
# 4.0 <class 'float'>
# Abdulaziz <class 'str'>
# True <class 'bool'>
# [85, 92, 78, 95, 88] <class 'list'>

# %%
def calculate_average(numbers):
    total = sum(numbers)
    count = len(numbers)
    return total / count

test1 = [80, 90, 70, 85, 95]
test2 = [55, 62, 48, 71]

print("Average 1:", calculate_average(test1))
print("Average 2:", calculate_average(test2))
# I copy pasted it and it did not work but when i asked it from AI it
# just rearrenged it and it worked
# Out:
# Average 1: 84.0
# Average 2: 59.0

# %%
cities = ["Tashkent", "Samarkand", "Bukhara", "Namangan", "Fergana"]

for index, city in enumerate(cities):
    print(f"Index {index}: {city}")
    # I started to understand a little bit
    # when i copy pasted from assignment it did not work again
    # keyin yana joylashuvini to'g'irlagandan keyin ishladi
# Out:
# Index 0: Tashkent
# Index 1: Samarkand
# Index 2: Bukhara
# Index 3: Namangan
# Index 4: Fergana

# %%
import random

exam_scores = [random.randint(0, 100) for _ in range(10)]
print("Scores:", exam_scores)

avg = calculate_average(exam_scores)
print(f"Class average: {avg:.1f}")

if avg >= 60:
    print("Result: PASS")
else:
    print("Result: FAIL")
# finally i did it on my own but I do not understand it yet
# Out:
# Scores: [61, 45, 40, 36, 20, 24, 68, 66, 42, 23]
# Class average: 42.5
# Result: FAIL
